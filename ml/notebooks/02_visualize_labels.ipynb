# %%
import os
import random
import cv2
import matplotlib.pyplot as plt

# %%
IMG_DIR = "../datasets/yolo_exam/images/train"
LBL_DIR = "../datasets/yolo_exam/labels/train"

img_name = random.choice(os.listdir(IMG_DIR))
img_path = os.path.join(IMG_DIR, img_name)
lbl_path = os.path.join(LBL_DIR, img_name.replace(".jpg", ".txt"))

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

h, w, _ = img.shape

with open(lbl_path) as f:
    for line in f:
        cls, xc, yc, bw, bh = map(float, line.split())
        x1 = int((xc - bw / 2) * w)
        y1 = int((yc - bh / 2) * h)
        x2 = int((xc + bw / 2) * w)
        y2 = int((yc + bh / 2) * h)

        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)

plt.figure(figsize=(8, 6))
plt.imshow(img)
plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 IMG_DIR = "../datasets/yolo_exam/images/train"
#       2 LBL_DIR = "../datasets/yolo_exam/labels/train"
# ----> 4 img_name = random.choice(os.listdir(IMG_DIR))
#       5 img_path = os.path.join(IMG_DIR, img_name)
#       6 lbl_path = os.path.join(LBL_DIR, img_name.replace(".jpg", ".txt"))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\random.py:378, in Random.choice(self, seq)
#     376 """Choose a random element from a non-empty sequence."""
#     377 # raises IndexError if seq is empty
# --> 378 return seq[self._randbelow(len(seq))]
#
# IndexError: list index out of range
